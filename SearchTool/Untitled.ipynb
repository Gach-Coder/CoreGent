# %%
import search_tool

# %%
q = "张雪机车价格"
#rsp = []
#for s in search_tool.ENGINES.values():
#    rsp.append(s.search(query=q))

# %%
result = []
st = search_tool.SearchTool()
#res = st.do_search(query=q,max_results=6,out=result)

# %%
r = st.web_search(query=q,max_results=6)
# Out:
# [SearchResult(title='29980元起,张雪两款新车发布,820RR够猛500RR有升级!', url='http://www.baidu.com/link?url=GBgmyJAC0LFsa1Ydc0zgJhh0PKmcV4NxLouDIeyIcsv9roPQNWANAZfKJvuGpG8_kp_B2myxggWWDC1vloobN-odq18aXCAQLeGbggI-Vum'), SearchResult(title='聊聊张雪旗下的摩托车,你会更喜欢哪一款呢?', url='http://www.baidu.com/link?url=GBgmyJAC0LFsa1Ydc0zgJhh0PKmcV4NxLouDIeyIcswkHifBiMRV2I8ja4BB5kH96LgUjvL6oanVFZe2piNeaRWmqul6TTrWr6pRJPJEjmO'), SearchResult(title='【张雪机车 500RR】张雪机车 500RR报价_张雪机车 500RR图片_汽车之家', url='http://www.baidu.com/link?url=bh8mriP1vRIyzfvWOPwYhH1xchQdBPlljlVzHlzjctxG5Tr1aVUzWCfWM3nzjDAInKGGa32nPLgB3zooKFZknq'), SearchResult(title='张雪机车产品价格', url='http://www.baidu.com/link?url=T5MXKF1UFCNY9YGJenfMqHAjbPaG79FXyjGtDfl-rw2oybzhleakBq5tDd7L6JHkryJO7d9qi8MMx0P78sAY6-nEcYp2MgQBVhrYei2wYGR1Kz6g_k3h2O0N4WQPg1cEHfunXdZJxHctGI1d_vLF9a'), SearchResult(title='西方巨头的天塌了!张雪神车仅卖4.38万,这谁顶得住?', url='http://www.baidu.com/link?url=GBgmyJAC0LFsa1Ydc0zgJhh0PKmcV4NxLouDIeyIcswkHifBiMRV2I8ja4BB5kH9tkuvT09LNXkcz5BkKx28EEcSPz7gfWoV4UyIgNAfYz_'),
# ...

# %%
r
# Out:
# '搜索: 张雪机车价格\n引擎: baidu  共 6 条结果\n──────────────────────────────────────────────────\n\n1. 29980元起,张雪两款新车发布,820RR够猛500RR有升级!\n   http://www.baidu.com/link?url=GBgmyJAC0LFsa1Ydc0zgJhh0PKmcV4NxLouDIeyIcsv9roPQNWANAZfKJvuGpG8_kp_B2myxggWWDC1vloobN-odq18aXCAQLeGbggI-Vum\n\n2. 聊聊张雪旗下的摩托车,你会更喜欢哪一款呢?\n   http://www.baidu.com/link?url=GBgmyJAC0LFsa1Ydc0zgJhh0PKmcV4NxLouDIeyIcswkHifBiMRV2I8ja4BB5kH96LgUjvL6oanVFZe2piNeaRWmqul6TTrWr6pRJPJEjmO\n\n3. 【张雪机车 500RR】张雪机车 500RR报价_张雪机车 500RR图片_汽车之家\n   http://www.baidu.com/link?url=bh8mriP1vRIyzfvWOPwYhH1xchQdBPlljlVzHlzjctxG5Tr1aVUzWCfWM3nzjDAInKGGa32nPLgB3zooKFZknq\n\n4. 张雪机车产品价格\n   http://www.baidu.com/link?url=T5MXKF1UFCNY9YGJenfMqHAjbPaG79FXyjGtDfl-rw2oybzhleakBq5tDd7L6JHkryJO7d9qi8MMx0P78sAY6-nEcYp2MgQBVhrYei2wYGR1Kz6g_k3h2O0N4WQPg1cEHfunXdZJxHctGI1d_vLF9a\n\n5. 西方巨头的天塌了!张雪神车仅卖4.38万,这谁顶得住?\n   http://www.baidu.com/link?url=GBgmyJAC0LFsa1Ydc0zgJhh0PKmcV4NxLouDIeyIcswkHifBiMRV2I8ja4BB5kH9tkuvT09LNXkcz5BkKx28EEcSPz7gfWoV4UyIgNAfYz_\n\n6. 张雪820RR上市,
# ...

# %%
q[-1]
# Out:
# '…'

# %%
search_tool.ENGINES.values()
# Out:
# dict_values([<search_tool.BaiduSearch object at 0x00000142986ADFD0>, <search_tool.BingSearch object at 0x00000142986AF230>, <search_tool.SogouSearch object at 0x00000142986AF380>])

# %%
searcher = search_tool.BaiduSearch()

# %%
rsp = searcher.search(query=q)

# %%
rsp
# Out:
# [SearchResult(title='29980元起,张雪两款新车发布,820RR够猛500RR有升级!', url='http://www.baidu.com/link?url=blCeWO8sjDp79_AyUaOnSgrPmCwDmkCplXhKNHAaioRwhvjW5tUhwFo_C13g9PBR03JMVmOM5VZ8fmQ1UxGovG1gpnN5pEiQ7-qyvs-8qvS'),
#  SearchResult(title='【张雪机车 500RR】张雪机车 500RR报价_张雪机车 500RR图片_汽车之家', url='http://www.baidu.com/link?url=yhcIvc69KoLIgsGFnCNPsMURCSIm2jrtw4h5GaOyOOvW-_ygI_KwkRMjvlCkNOXDLXrOJjgV6JjPeeZZ2vc2SK'),
#  SearchResult(title='聊聊张雪旗下的摩托车,你会更喜欢哪一款呢?', url='http://www.baidu.com/link?url=blCeWO8sjDp79_AyUaOnSgrPmCwDmkCplXhKNHAaioPpjfnM2EBLvKMJNx7_0zP1rUHjbWH7Q4QDFhjjVC8uYX-wLF4F_fN2Q6LjM3D6um7'),
#  SearchResult(title='张雪机车全系车型价格大揭秘', url='http://www.baidu.com/link?url=pMReP-9pbhMyZmUKoErOrAsEXl6o4i33zXu_CWTKJTgG0TJhbK37HRkVkaw4IteVnbHko-6D8KHsBDNRcJBixBZsrtN_hxb6w9JnldNI36d_1EX-WqdiLENAoZZkrr2e'),
#  SearchResult(title='张雪机车摩托车整车怎么样 中国摩托杀疯了!赛道上直接碾压一众...', url='http://www.baidu.com/link?url=pMReP-9pbhMyZmUKoErOrI7A6S7DjHtJKBZm6K7PrDSlu3f1Yq40R04ZF_7yY7-NGzahrPkXUuZy2hberZhMl_'),
# ...

# %%
[v for v in search_tool.ENGINES.values()][0]
